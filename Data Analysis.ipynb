# %%
import requests
from bs4 import BeautifulSoup

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install bs4
# Out:
# ...
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1272 sha256=e1c0ec0f53628bc628e9dcb2cac10c1cfb0862b2654e874326d753c3f32a472c
#   Stored in directory: /Users/harshit/Library/Caches/pip/wheels/75/78/21/68b124549c9bdc94f822c02fb9aa3578a669843f9767776bca
# Successfully built bs4
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
url = "https://www.amazon.co.uk/introducing-fire-tv-stick-lite-with-alexa-voice-remote-lite-no-tv-controls-2020-release/product-reviews/B07ZZW7QCM/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews"

# %%
headers={"user-agent":"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_6) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/13.1.2 Safari/605.1.15"}

# %%
page=requests.get(url, headers=headers)

# %%
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content, "html.parser")

# %%
print(soup.title.name)
# Out:
# title

# %%
soup.title
# Out:
# <title>Amazon.co.uk:Customer reviews: Introducing Fire TV Stick Lite with Alexa Voice Remote Lite (no TV controls) | HD streaming device | 2020 release</title>

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-gb"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <script type="text/javascript">var ue_t0=ue_t0||+new Date();</script>
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
# <link href="https://completion.amazon.com" rel="dns-prefetch"/>
# <script type="text/javascript">
# window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# var ue_csm = window,
#     ue_hob = +new Date();
# ...

# %%
soup.prettify
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-gb"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <script type="text/javascript">var ue_t0=ue_t0||+new Date();</script>
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
# <link href="https://completion.amazon.com" rel="dns-prefetch"/>
# <script type="text/javascript">
# window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# var ue_csm = window,
#     ue_hob = +new Date();
# ...

# %%
for a in soup.find_all('div', attrs={'class':'a-section a-spacing-none review-views celwidget'}):
    print(a)
# Out:
# <div class="a-section a-spacing-none review-views celwidget" id="cm_cr-review_list"><h3 class="a-spacing-medium" data-hook="arp-local-reviews-header">
#
#
#
#
#
#
#
#
# From United Kingdom
# ...

# %%
author_name = a.find_all('span',attrs={'class':'a-profile-name'})
print(author_name)
# Out:
# [<span class="a-profile-name">George</span>, <span class="a-profile-name">MarksRemarks</span>, <span class="a-profile-name">Ian H</span>, <span class="a-profile-name">Madacksman</span>, <span class="a-profile-name">caz2🛍</span>, <span class="a-profile-name">erics kid</span>, <span class="a-profile-name">Kindle Customer</span>, <span class="a-profile-name">D Doyle</span>, <span class="a-profile-name">Lilah Ivy</span>, <span class="a-profile-name">Shopper man</span>]
