# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install bs4
# Out:
# ...
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1272 sha256=e1c0ec0f53628bc628e9dcb2cac10c1cfb0862b2654e874326d753c3f32a472c
#   Stored in directory: /Users/harshit/Library/Caches/pip/wheels/75/78/21/68b124549c9bdc94f822c02fb9aa3578a669843f9767776bca
# Successfully built bs4
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
url = 'https://www.amazon.co.uk/Crocs-10001C-Unisex-Adults-Classic-Clogs/product-reviews/B07SY42YY9/ref=cm_cr_getr_d_paging_btm_next_'+str(2)+'?ie=UTF8&reviewerType=all_reviews&pageNumber='+str(2)
headers={"user-agent":"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_6) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/13.1.2 Safari/605.1.15"}
page=requests.get(url, headers=headers)
print(page)
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content, "html.parser")

# %%
print(soup.title)
# Out:
# <title>Amazon.co.uk:Customer reviews: Crocs Unisex Classic Clogs</title>

# %%
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-gb"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <script type="text/javascript">var ue_t0=ue_t0||+new Date();</script>
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
# <link href="https://completion.amazon.com" rel="dns-prefetch"/>
# <script type="text/javascript">
# window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# var ue_csm = window,
#     ue_hob = +new Date();
# ...

# %%
def fetch_url_data(pageNo):
    url = 'https://www.amazon.co.uk/Crocs-10001C-Unisex-Adults-Classic-Clogs/product-reviews/B07SY42YY9/ref=cm_cr_getr_d_paging_btm_next_'+str(pageNo)+'?ie=UTF8&reviewerType=all_reviews&pageNumber='+str(pageNo)
    table = []
    for a in soup.find_all('div', attrs={'class':'a-section review aok-relative'}):
        author_name = a.find('span',attrs={'class':'a-profile-name'})
        title = a.find('a', attrs={'class':'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold'})
        rating = a.find('span', attrs={'class':'a-icon-alt'})
        review = a.find('span', attrs={'class':'a-size-base review-text review-text-content'})
        size = a.find('div', attrs={'class':'a-row a-spacing-mini review-data review-format-strip'})
        helpfullness = a.find('div', attrs={'class':'a-row a-spacing-small'})
        
        columns=[]
        if title is not None:
            columns.append(title.text)
        if author_name is not None:
            columns.append(author_name.text)
        if rating is not None:
            columns.append(rating.text)
        if review is not None:
            columns.append(review.text)
        if size is not None:
            columns.append(size.text)
        if helpfullness is not None:   
            columns.append(helpfullness.text)        
            
        table.append(columns)
            
    return table

# %%
complete_data = []
for i in range(1, 7000):
    complete_data.append(fetch_url_data(i))
flatten = lambda l: [item for sublist in l for item in sublist]

# %%
df = pd.DataFrame(flatten(complete_data),columns=['Title','Author Name','Rating','Review', 'Size', 'Helpfullness'])
df.tail(50)
# Out:
#                                                    Title         Author Name  \
# 69940                          \nExpensive but quality\n          emenjayell
# 69941  \nExtremely comfortable 🙂 never have them off ...  Michelle Gilliard
# 69942                                  \nSizing issues\n               Kel99
# 69943                   \nSort out your sizing, Crocs!\n   Countess Perpetua
# 69944                             \nCrocs, nuff  said.\n         Planetpeeps
# 69945  \nThese might not look the best buy omg are th...                 Bob
# 69946                               \nCrocs are Crocs!\n               Mrs P
# 69947                     \nCroc Convert (+ Size tip!)\n              Cesc15
# 69948                           \nA Good exam question\n               James
# 69949                     \nLOVE, LOVE, LOVE my Crocs!\n          Cate Jones
# 69950                          \nExpensive but quality\n          emenjayell
# ...

# %%
df.to_csv('crocs_review.csv', index=False, encoding='utf-8')

# %% [markdown]
# ## File import

# %%
df = pd.read_csv("crocs_review.csv")

# %%
#df.info()

# %%
#df.describe()

# %%
df['Title'] = df['Title'].replace('\n', '',regex=True)
df['Review'] = df['Review'].replace('\n', '',regex=True)
df.head()
# Out:
#                                                Title         Author Name  \
# 0                              Expensive but quality          emenjayell
# 1  Extremely comfortable 🙂 never have them off my...  Michelle Gilliard
# 2                                      Sizing issues               Kel99
# 3                       Sort out your sizing, Crocs!   Countess Perpetua
# 4                                 Crocs, nuff  said.         Planetpeeps
#
#                Rating                                             Review  \
# 0  5.0 out of 5 stars    Much much better than the cheapo copies avai...
# 1  5.0 out of 5 stars    I bought these back in August, never have th...
# 2  3.0 out of 5 stars    I eventually swapped to Crocs Unisex-Adult's...
# 3  2.0 out of 5 stars    Others have commented on the strange sizing ...
# 4  5.0 out of 5 stars    Crocs are, for me, functional footware. I on...
#
#                                                 Size  \
# ...

# %%
df[['Size','Colour']] = df['Size'].str.split("Colour:",expand=True)
df.head()
# Out:
#                                                Title         Author Name  \
# 0                              Expensive but quality          emenjayell
# 1  Extremely comfortable 🙂 never have them off my...  Michelle Gilliard
# 2                                      Sizing issues               Kel99
# 3                       Sort out your sizing, Crocs!   Countess Perpetua
# 4                                 Crocs, nuff  said.         Planetpeeps
#
#                Rating                                             Review  \
# 0  5.0 out of 5 stars    Much much better than the cheapo copies avai...
# 1  5.0 out of 5 stars    I bought these back in August, never have th...
# 2  3.0 out of 5 stars    I eventually swapped to Crocs Unisex-Adult's...
# 3  2.0 out of 5 stars    Others have commented on the strange sizing ...
# 4  5.0 out of 5 stars    Crocs are, for me, functional footware. I on...
#
#                          Size                   Helpfullness  \
# ...

# %%
df[['Men Size','Women Size']] = df['Size'].str.split("/",expand=True)
df.head()
# Out:
#                                                Title         Author Name  \
# 0                              Expensive but quality          emenjayell
# 1  Extremely comfortable 🙂 never have them off my...  Michelle Gilliard
# 2                                      Sizing issues               Kel99
# 3                       Sort out your sizing, Crocs!   Countess Perpetua
# 4                                 Crocs, nuff  said.         Planetpeeps
#
#                Rating                                             Review  \
# 0  5.0 out of 5 stars    Much much better than the cheapo copies avai...
# 1  5.0 out of 5 stars    I bought these back in August, never have th...
# 2  3.0 out of 5 stars    I eventually swapped to Crocs Unisex-Adult's...
# 3  2.0 out of 5 stars    Others have commented on the strange sizing ...
# 4  5.0 out of 5 stars    Crocs are, for me, functional footware. I on...
#
#                          Size                   Helpfullness  \
# ...

# %%
df['Men Size'] = df['Men Size'].str.extract('(\d+.\d+)')
df.head()
# Out:
#                                                Title         Author Name  \
# 0                              Expensive but quality          emenjayell
# 1  Extremely comfortable 🙂 never have them off my...  Michelle Gilliard
# 2                                      Sizing issues               Kel99
# 3                       Sort out your sizing, Crocs!   Countess Perpetua
# 4                                 Crocs, nuff  said.         Planetpeeps
#
#                Rating                                             Review  \
# 0  5.0 out of 5 stars    Much much better than the cheapo copies avai...
# 1  5.0 out of 5 stars    I bought these back in August, never have th...
# 2  3.0 out of 5 stars    I eventually swapped to Crocs Unisex-Adult's...
# 3  2.0 out of 5 stars    Others have commented on the strange sizing ...
# 4  5.0 out of 5 stars    Crocs are, for me, functional footware. I on...
#
#                          Size                   Helpfullness  \
# ...
