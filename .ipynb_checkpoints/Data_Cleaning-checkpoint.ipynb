# %% [markdown]
# Let's start by importing the relevant libraries required for our Data Cleaning process.

# %%
import pandas as pd #Used to read .csv file and for analysis task on dataframe.

# %% [markdown]
# ### Start by reading the csv file using Pandas
# Let's read the `crocs_reviews.csv` file which contains the scrapped data into a dataframe.

# %%
df = pd.read_csv("crocs_reviews.csv")

# %%
df
# Out:
#                                                   Title          Author Name  \
# 0        \nNot the good made in USA ones of years ago\n  Outdoor Enthusiast!
# 1     \nTwo completely different sized shoes marked ...      MoMo Wondertoes
# 2                                \nLove Crocs but....\n                  PJM
# 3                                 \nNot buying Crocs.\n               Shemit
# 4                               \nDidn't last a month\n      Amazon Customer
# ...                                                 ...                  ...
# 8691                                 \nJust buy crocs\n               Tim H.
# 8692                                         \nreview\n            Avainyuna
# 8693                                      \nVery nice\n    Patricia L. Meyer
# 8694                                     \nGreat buy.\n               K. lee
# 8695                   \nCan’t beat it for the price.\n              run-jon
#
#                   Rating                                             Review  \
# 0     1.0 out of 5 stars  \n\n  I have worn Crocs for years, but the wel...
# 1     1.0 out of 5 stars  \n\n  We have been buying crocs for a long tim...
# 2     1.0 out of 5 stars  \n\n  I was hoping these would fit like the Cl...
# 3     1.0 out of 5 stars  \n\n  I would never recommend the now-a-day Cr...
# 4     1.0 out of 5 stars  \n\n  I bought these to replace an earlier pai...
# ...                  ...                                                ...
# 8691  5.0 out of 5 stars  \n\n  Crocs are great, simple and comfortable ...
# 8692  5.0 out of 5 stars  \n\n\n  Your browser does not support HTML5 vi...
# 8693  5.0 out of 5 stars  \n\n  Bought for granddaughter, she loves them...
# 8694  5.0 out of 5 stars  \n\n  Fits and feels very comfortable. Perfect...
# 8695  5.0 out of 5 stars             \n\n  Can’t beat it for the price.\n\n
#
#                                        Size                   Helpfullness  \
# 0     Size: 9 Women/7 MenColor: Grass Green  367 people found this helpful
# 1           Size: 7 Women/5 MenColor: Black  327 people found this helpful
# 2            Size: 9 Women/7 MenColor: Navy  157 people found this helpful
# 3           Size: 7 Women/5 MenColor: Black  154 people found this helpful
# 4           Size: 11 Women/9 MenColor: Navy   71 people found this helpful
# ...                                     ...                            ...
# 8691        Size: 6 Women/4 MenColor: Black                            NaN
# 8692        Size: 8 Women/6 MenColor: White                            NaN
# 8693     Size: 9 Women/7 MenColor: New Mint                            NaN
# 8694        Size: 11 Women/9 MenColor: Navy                            NaN
# 8695       Size: 10 Women/8 MenColor: Black                            NaN
#
#                                             Review_Date
# 0        Reviewed in the United States on July 18, 2018
# 1       Reviewed in the United States on August 6, 2017
# 2        Reviewed in the United States on June 25, 2018
# 3         Reviewed in the United States on May 27, 2017
# 4     Reviewed in the United States on November 2, 2018
# ...                                                 ...
# 8691      Reviewed in the United States on July 3, 2019
# 8692  Reviewed in the United States on October 23, 2020
# 8693      Reviewed in the United States on May 22, 2019
# 8694  Reviewed in the United States on January 15, 2019
# 8695     Reviewed in the United States on July 19, 2019
#
# [8696 rows x 7 columns]

# %% [markdown]
# Pandas make it very easy to read the data from a data frame. From here we can see that the data frame contains 7 columns and 8696 rows. Each column needs to go through multiple steps for cleaning the data to bring it in a better format to carry the analysis part.
#
# Let's view some basic information about the data frame using the `.info` method.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8696 entries, 0 to 8695
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Title         7156 non-null   object
#  1   Author Name   8696 non-null   object
#  2   Rating        8696 non-null   object
#  3   Review        8696 non-null   object
#  4   Size          8480 non-null   object
#  5   Helpfullness  1222 non-null   object
#  6   Review_Date   8696 non-null   object
# dtypes: object(7)
# memory usage: 475.7+ KB

# %% [markdown]
# Here, we can see that their are many `null` values in multiple columns. So it is important to remove those null values with the suitable values. Also, the datatype for each column is `object` which needs to be corrected according to the data contained in that column.

# %%
df.isnull().any()
# Out:
# Title            True
# Author Name     False
# Rating          False
# Review          False
# Size             True
# Helpfullness     True
# Review_Date     False
# dtype: bool

# %% [markdown]
# ### We will start the cleaning process column-wise.
# We start by cleaning the first column that is Title. Here, by looking at the dataset we can see that there are multiple '\n' at the beginning and the end of every value. So we remove those values to get clear string values.
#
# Secondly, we know from the `.info` method that there are null values in this column, which we will replace by 'No title' string.

# %%
df['Title'] = df['Title'].replace('\n', '',regex=True)
df['Title'] = df['Title'].fillna('No Title') # We replace the nan values with 'No title' string.
df.head()
# Out:
#                                                Title          Author Name  \
# 0         Not the good made in USA ones of years ago  Outdoor Enthusiast!
# 1  Two completely different sized shoes marked th...      MoMo Wondertoes
# 2                                 Love Crocs but....                  PJM
# 3                                  Not buying Crocs.               Shemit
# 4                                Didn't last a month      Amazon Customer
#
#                Rating                                             Review  \
# 0  1.0 out of 5 stars  \n\n  I have worn Crocs for years, but the wel...
# 1  1.0 out of 5 stars  \n\n  We have been buying crocs for a long tim...
# 2  1.0 out of 5 stars  \n\n  I was hoping these would fit like the Cl...
# 3  1.0 out of 5 stars  \n\n  I would never recommend the now-a-day Cr...
# 4  1.0 out of 5 stars  \n\n  I bought these to replace an earlier pai...
#
#                                     Size                   Helpfullness  \
# 0  Size: 9 Women/7 MenColor: Grass Green  367 people found this helpful
# 1        Size: 7 Women/5 MenColor: Black  327 people found this helpful
# 2         Size: 9 Women/7 MenColor: Navy  157 people found this helpful
# 3        Size: 7 Women/5 MenColor: Black  154 people found this helpful
# 4        Size: 11 Women/9 MenColor: Navy   71 people found this helpful
#
#                                          Review_Date
# 0     Reviewed in the United States on July 18, 2018
# 1    Reviewed in the United States on August 6, 2017
# 2     Reviewed in the United States on June 25, 2018
# 3      Reviewed in the United States on May 27, 2017
# 4  Reviewed in the United States on November 2, 2018

# %% [markdown]
# Next we clean the `Rating` column by removing the unwanted strings and just keeping the rating count. After which we convert it to the numeric datatype from the object type. In this column we don't have to worry about the null values as there are no null values.

# %%
df['Rating'] = df['Rating'].str.extract('(\d+.\d+|\d+)')
df['Rating'] = pd.to_numeric(df['Rating'], errors='coerce', downcast='integer')

# %% [markdown]
# On the `Review` column, We perform similar steps which we performed on the `Title` column as there are multiple '\n' values in this column as well.

# %%
df['Review'] = df['Review'].replace('\n', '',regex=True)

# %% [markdown]
# Next we go to the `Size` column which contains three different values which can be divided into multiple columns. So we follow the below steps:
# 1. We separate out the color of the crocs and form a new column called Colour.
# 2. After removing the Color from the `Size` column we can see that it contains two values which can be divided into two columns, that is, `Men Size` and `Women Size`.
# 3. To make the calculations simpler, we extract only the numerical values from the Men Size and Women Size columns.
# 4. After ectraction, we convert the object datatype to numeric.

# %%
df[['Size','Colour']] = df['Size'].str.split("Color:",expand=True)

# %%
df[['Men Size','Women Size']] = df['Size'].str.split("/",expand=True)
del df['Size']

# %%
df['Men Size'] = df['Men Size'].str.extract('(\d+.\d+|\d+)')
df['Women Size'] = df['Women Size'].str.extract('(\d+.\d+|\d+)')
df['Men Size'] = pd.to_numeric(df['Men Size'], errors='coerce')
df['Women Size'] = pd.to_numeric(df['Women Size'], errors='coerce')
df.head()
# Out:
#                                                Title          Author Name  \
# 0         Not the good made in USA ones of years ago  Outdoor Enthusiast!
# 1  Two completely different sized shoes marked th...      MoMo Wondertoes
# 2                                 Love Crocs but....                  PJM
# 3                                  Not buying Crocs.               Shemit
# 4                                Didn't last a month      Amazon Customer
#
#    Rating                                             Review  \
# 0       1    I have worn Crocs for years, but the well-ma...
# 1       1    We have been buying crocs for a long time an...
# 2       1    I was hoping these would fit like the Classi...
# 3       1    I would never recommend the now-a-day Crocs ...
# 4       1    I bought these to replace an earlier pair wh...
#
#                     Helpfullness  \
# 0  367 people found this helpful
# 1  327 people found this helpful
# 2  157 people found this helpful
# 3  154 people found this helpful
# 4   71 people found this helpful
#
#                                          Review_Date        Colour  Men Size  \
# 0     Reviewed in the United States on July 18, 2018   Grass Green       9.0
# 1    Reviewed in the United States on August 6, 2017         Black       7.0
# 2     Reviewed in the United States on June 25, 2018          Navy       9.0
# 3      Reviewed in the United States on May 27, 2017         Black       7.0
# 4  Reviewed in the United States on November 2, 2018          Navy      11.0
#
#    Women Size
# 0         7.0
# 1         5.0
# 2         7.0
# 3         5.0
# 4         9.0

# %%
df.isnull().sum()
# Out:
# Title              0
# Author Name        0
# Rating             0
# Review             0
# Helpfullness    7474
# Review_Date        0
# Colour           216
# Men Size         216
# Women Size       284
# dtype: int64

# %% [markdown]
# As we can notice that `Men Size` , `Women Size` and `Colour` columns have nan values. So to we can replace those nan values by the mode values of the respective columns.

# %%
df['Men Size'].fillna(df['Men Size'].mode()[0], inplace=True)
df['Women Size'].fillna(df['Women Size'].mode()[0], inplace=True)
df['Colour'].fillna(df['Colour'].mode()[0], inplace=True)

# %% [markdown]
# Let's clean the `Helpfullness` column now. We have a mix of strings, nan values and we need only the numerical values. So let's follow the below steps:
# <ol>
# <li> Remove the unwanted string and just keep the numerical value, which is the number at index 0.
# <li> Remove the comma separator from the numbers having more than 3 digits.
# <li> Replace the string one by the numerical 1.
# <li> Replace the nan values with '0'.
# <li> Convert the datatype from object to integer.
# </ol>

# %%
df['Helpfullness'] = df['Helpfullness'].str.split().str.get(0)
df['Helpfullness'] = df['Helpfullness'].str.replace(',','')
df['Helpfullness'] = df['Helpfullness'].str.replace('One','1')
df['Helpfullness'] = df['Helpfullness'].fillna(0) # We replace the nan values with '0'.
df['Helpfullness'] = df['Helpfullness'].astype('int32')
df.head()
# Out:
#                                                Title          Author Name  \
# 0         Not the good made in USA ones of years ago  Outdoor Enthusiast!
# 1  Two completely different sized shoes marked th...      MoMo Wondertoes
# 2                                 Love Crocs but....                  PJM
# 3                                  Not buying Crocs.               Shemit
# 4                                Didn't last a month      Amazon Customer
#
#    Rating                                             Review  Helpfullness  \
# 0       1    I have worn Crocs for years, but the well-ma...           367
# 1       1    We have been buying crocs for a long time an...           327
# 2       1    I was hoping these would fit like the Classi...           157
# 3       1    I would never recommend the now-a-day Crocs ...           154
# 4       1    I bought these to replace an earlier pair wh...            71
#
#                                          Review_Date        Colour  Men Size  \
# 0     Reviewed in the United States on July 18, 2018   Grass Green       9.0
# 1    Reviewed in the United States on August 6, 2017         Black       7.0
# 2     Reviewed in the United States on June 25, 2018          Navy       9.0
# 3      Reviewed in the United States on May 27, 2017         Black       7.0
# 4  Reviewed in the United States on November 2, 2018          Navy      11.0
#
#    Women Size
# 0         7.0
# 1         5.0
# 2         7.0
# 3         5.0
# 4         9.0

# %% [markdown]
# Finally, we work on the `Review_Date` column. In this we need to extract only the year but as we can see that it contains multiple strings. So we perform the following process:
# <ol>
#     <li> We remove the starting strings and keep only the date part.
#     <li> By using the <b>datetime</b> library we convert the string to the datetime format.
#     <li> Now it becomes easy to extract only the year part from the date.
# </ol>

# %%
from datetime import datetime
df['Review_Date'] = df['Review_Date'].str.strip().str[-4:]
df['Review_Date'] = pd.to_datetime(df['Review_Date'], errors='coerce').dt.year
df.head()
# Out:
#                                                Title          Author Name  \
# 0         Not the good made in USA ones of years ago  Outdoor Enthusiast!
# 1  Two completely different sized shoes marked th...      MoMo Wondertoes
# 2                                 Love Crocs but....                  PJM
# 3                                  Not buying Crocs.               Shemit
# 4                                Didn't last a month      Amazon Customer
#
#    Rating                                             Review  Helpfullness  \
# 0       1    I have worn Crocs for years, but the well-ma...           367
# 1       1    We have been buying crocs for a long time an...           327
# 2       1    I was hoping these would fit like the Classi...           157
# 3       1    I would never recommend the now-a-day Crocs ...           154
# 4       1    I bought these to replace an earlier pair wh...            71
#
#    Review_Date        Colour  Men Size  Women Size
# 0         2018   Grass Green       9.0         7.0
# 1         2017         Black       7.0         5.0
# 2         2018          Navy       9.0         7.0
# 3         2017         Black       7.0         5.0
# 4         2018          Navy      11.0         9.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8696 entries, 0 to 8695
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Title         8696 non-null   object
#  1   Author Name   8696 non-null   object
#  2   Rating        8696 non-null   int8
#  3   Review        8696 non-null   object
#  4   Helpfullness  8696 non-null   int32
#  5   Review_Date   8696 non-null   int64
#  6   Colour        8696 non-null   object
#  7   Men Size      8696 non-null   float64
#  8   Women Size    8696 non-null   float64
# dtypes: float64(2), int32(1), int64(1), int8(1), object(4)
# memory usage: 518.1+ KB

# %%
df.describe()
# Out:
#             Rating  Helpfullness  Review_Date     Men Size   Women Size
# count  8696.000000   8696.000000  8696.000000  8696.000000  8696.000000
# mean      3.670538      1.782544  2018.361431    10.072677     8.033579
# std       1.549828     34.314102     2.156366     2.652287     2.645690
# min       1.000000      0.000000  2007.000000     4.000000     2.000000
# 25%       2.000000      0.000000  2017.000000     8.000000     6.000000
# 50%       5.000000      0.000000  2019.000000    10.000000     7.500000
# 75%       5.000000      0.000000  2020.000000    12.000000    10.000000
# max       5.000000   1920.000000  2020.000000    19.000000    17.000000

# %% [markdown]
# As the final step we rearrange the columns to the desired arrangement and rename them for better understanding.

# %%
df = df[['Author Name','Title','Review','Rating','Colour','Men Size','Women Size','Helpfullness','Review_Date']]
df = df.rename(columns={"Author Name": "author_name", "Title": "review_title", "Review": "review_text", 
                   "Rating": "product_rating", "Colour": "product_colour", "Men Size": "men_size", "Women Size": "women_size",
                   "Helpfullness": "review_helpfullness", 
                   "Review_Date": "review_date"}, errors="raise")

# %%
df
# Out:
#               author_name                                       review_title  \
# 0     Outdoor Enthusiast!         Not the good made in USA ones of years ago
# 1         MoMo Wondertoes  Two completely different sized shoes marked th...
# 2                     PJM                                 Love Crocs but....
# 3                  Shemit                                  Not buying Crocs.
# 4         Amazon Customer                                Didn't last a month
# ...                   ...                                                ...
# 8691               Tim H.                                     Just buy crocs
# 8692            Avainyuna                                             review
# 8693    Patricia L. Meyer                                          Very nice
# 8694               K. lee                                         Great buy.
# 8695              run-jon                       Can’t beat it for the price.
#
#                                             review_text  product_rating  \
# 0       I have worn Crocs for years, but the well-ma...               1
# 1       We have been buying crocs for a long time an...               1
# 2       I was hoping these would fit like the Classi...               1
# 3       I would never recommend the now-a-day Crocs ...               1
# 4       I bought these to replace an earlier pair wh...               1
# ...                                                 ...             ...
# 8691     Crocs are great, simple and comfortable always               5
# 8692    Your browser does not support HTML5 video.  ...               5
# 8693           Bought for granddaughter, she loves them               5
# 8694    Fits and feels very comfortable. Perfect for...               5
# 8695                       Can’t beat it for the price.               5
#
#      product_colour  men_size  women_size  review_helpfullness  review_date
# 0       Grass Green       9.0         7.0                  367         2018
# 1             Black       7.0         5.0                  327         2017
# 2              Navy       9.0         7.0                  157         2018
# 3             Black       7.0         5.0                  154         2017
# 4              Navy      11.0         9.0                   71         2018
# ...             ...       ...         ...                  ...          ...
# 8691          Black       6.0         4.0                    0         2019
# 8692          White       8.0         6.0                    0         2020
# 8693       New Mint       9.0         7.0                    0         2019
# 8694           Navy      11.0         9.0                    0         2019
# 8695          Black      10.0         8.0                    0         2019
#
# [8696 rows x 9 columns]

# %% [markdown]
# Finally Let's save this cleaned dataset in a new `.csv` file.

# %%
df.to_csv('crocs_reviews_cleaned.csv', index=False, encoding='utf-8')
